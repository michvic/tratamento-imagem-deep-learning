# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/Colab Notebooks/plantdisease/bd100/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
import numpy as np
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage

import os
import glob

ext_img = '.jpg'
num_px = 100
num_py = 100
total_imgs = 16642     # total of images considering all classes
base_name = '/content/gdrive/My Drive/Colab Notebooks/plantdiseases/bd100' # main folder

# Training parameters
batch_size = 64  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = False
num_classes = 20

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True


ROOT_PATH = os.path.abspath(base_name)#retorna o caminho completo da pasta ./base
dir = os.listdir(ROOT_PATH)# lista todos arquivos/pastas do diretorio ./base
dir.sort()

labels_dic = {}

labels = np.zeros((total_imgs, 1))
data = np.zeros((total_imgs, num_py, num_px, 3))

count = 0
countImg = 0

for pasta in dir:
    if os.path.isdir(ROOT_PATH + '/' + pasta):
        labels_dic[count] = pasta # cria os labels relacionando um dicetorio com um número

        imgs = glob.glob(ROOT_PATH + '/' + pasta + '/*' + ext_img)
        #imgs.sort()
        for pathImg in imgs:
            #image = np.array(ndimage.imread(pathImg, flatten=False))
            image = np.array(plt.imread(pathImg, format='JPG'))
            #converter image para (90,100)
            data[countImg, :, :, :] = image
            labels[countImg, :] = count
            countImg += 1
        count += 1

        print('#images converted:', countImg)


print('#labels:', count)

#Train Test Split
x_train = data.reshape(data.shape[0], -1)
print("Shape of data_flatten: ", data.shape)
print("Shape of labels: ", labels.shape)

x_train, x_test, y_train, y_test = train_test_split(x_train, labels.astype('uint8'), test_size=0.3, random_state=0)

#x_train = x_train.astype('float32')
#x_test = x_test.astype('float32')

# Perform one-hot encoding on the labels
#y_train = to_categorical(y_train, num_classes=num_classes)
#y_test = to_categorical(y_test, num_classes=num_classes)

# Reshape image in 3 dimensions (height = 75px, width = 100px , canal = 3)
x_train = x_train.reshape(x_train.shape[0], *(num_py, num_px, 3))
x_test = x_test.reshape(x_test.shape[0], *(num_py, num_px, 3))

print("Train shape" + str(x_train.shape))
print("Test shape" + str(x_test.shape))

n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(input_shape, depth, num_classes=num_classes):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=num_classes):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'XDB100_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        steps_per_epoch=x_train.shape[0] // batch_size,
                        validation_data=(x_test, y_test),
                        validation_steps=x_test.shape[0] // batch_size,
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using TensorFlow backend.
# #images converted: 646
# #images converted: 2418
# #images converted: 3553
# #images converted: 3951
# #images converted: 5076
# #images converted: 5463
# #images converted: 5796
# #images converted: 6158
# #images converted: 6500
# #images converted: 7333
# #images converted: 8754
# #images converted: 9153
# #images converted: 9900
# #images converted: 10926
# #images converted: 12968
# #images converted: 13693
# #images converted: 14039
# #images converted: 14592
# #images converted: 15744
# #images converted: 16642
# #labels: 20
# Shape of data_flatten:  (16642, 100, 100, 3)
# Shape of labels:  (16642, 1)
# Train shape(11649, 100, 100, 3)
# Test shape(4993, 100, 100, 3)
# x_train shape: (11649, 100, 100, 3)
# 11649 train samples
# 4993 test samples
# y_train shape: (11649, 1)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 100, 100, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 100, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 100, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 100, 100, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 100, 100, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 100, 100, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 100, 100, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 100, 100, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 100, 100, 16) 64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100, 100, 16) 0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100, 100, 16) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 100, 100, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 100, 100, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100, 100, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 100, 100, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 100, 100, 16) 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 100, 100, 16) 0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100, 100, 16) 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 100, 100, 16) 2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 100, 100, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 100, 100, 16) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 100, 100, 16) 2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 100, 100, 16) 64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100, 100, 16) 0           activation_5[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 100, 100, 16) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 50, 50, 32)   4640        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50, 50, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 32)   544         activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 32)   0           conv2d_10[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 50, 50, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 50, 50, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 50, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50, 50, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 50, 50, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 50, 50, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 50, 50, 32)   0           activation_9[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 50, 50, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 50, 50, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 50, 50, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 50, 50, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 50, 50, 32)   9248        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 50, 50, 32)   128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 50, 50, 32)   0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 50, 50, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   18496       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 25, 25, 64)   2112        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 25, 25, 64)   0           conv2d_17[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 25, 25, 64)   36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 25, 25, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 25, 25, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 25, 25, 64)   0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 25, 25, 64)   0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 25, 25, 64)   36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 25, 25, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 25, 25, 64)   36928       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 25, 25, 64)   0           activation_17[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 25, 25, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 3, 3, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 576)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 20)           11540       flatten_1[0][0]
# ==================================================================================================
# Total params: 285,332
# Trainable params: 283,956
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1
# Not using data augmentation.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 11649 samples, validate on 4993 samples
# Epoch 1/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 41s 3ms/step - loss: 1.4990 - acc: 0.5879 - val_loss: 2.8067 - val_acc: 0.4382
#
# Epoch 00001: val_acc improved from -inf to 0.43821, saving model to /content/saved_models/XDB100_ResNet20v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.9207 - acc: 0.7511 - val_loss: 1.5476 - val_acc: 0.6467
#
# Epoch 00002: val_acc improved from 0.43821 to 0.64671, saving model to /content/saved_models/XDB100_ResNet20v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.7665 - acc: 0.8000 - val_loss: 1.0306 - val_acc: 0.7144
#
# Epoch 00003: val_acc improved from 0.64671 to 0.71440, saving model to /content/saved_models/XDB100_ResNet20v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.6665 - acc: 0.8279 - val_loss: 0.7986 - val_acc: 0.7871
#
# Epoch 00004: val_acc improved from 0.71440 to 0.78710, saving model to /content/saved_models/XDB100_ResNet20v1_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.5694 - acc: 0.8633 - val_loss: 0.8237 - val_acc: 0.7795
#
# Epoch 00005: val_acc did not improve from 0.78710
# Epoch 6/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.5512 - acc: 0.8715 - val_loss: 0.5803 - val_acc: 0.8574
#
# Epoch 00006: val_acc improved from 0.78710 to 0.85740, saving model to /content/saved_models/XDB100_ResNet20v1_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.5018 - acc: 0.8832 - val_loss: 0.7843 - val_acc: 0.8025
#
# Epoch 00007: val_acc did not improve from 0.85740
# Epoch 8/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.4361 - acc: 0.9065 - val_loss: 0.5061 - val_acc: 0.8786
#
# Epoch 00008: val_acc improved from 0.85740 to 0.87863, saving model to /content/saved_models/XDB100_ResNet20v1_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.4418 - acc: 0.9054 - val_loss: 0.5790 - val_acc: 0.8572
#
# Epoch 00009: val_acc did not improve from 0.87863
# Epoch 10/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.4181 - acc: 0.9130 - val_loss: 0.8578 - val_acc: 0.7961
#
# Epoch 00010: val_acc did not improve from 0.87863
# Epoch 11/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.4047 - acc: 0.9164 - val_loss: 0.5647 - val_acc: 0.8652
#
# Epoch 00011: val_acc did not improve from 0.87863
# Epoch 12/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3563 - acc: 0.9302 - val_loss: 0.5057 - val_acc: 0.8798
#
# Epoch 00012: val_acc improved from 0.87863 to 0.87983, saving model to /content/saved_models/XDB100_ResNet20v1_model.012.h5
# Epoch 13/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3635 - acc: 0.9294 - val_loss: 0.6372 - val_acc: 0.8646
#
# Epoch 00013: val_acc did not improve from 0.87983
# Epoch 14/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3883 - acc: 0.9227 - val_loss: 0.5665 - val_acc: 0.8706
#
# Epoch 00014: val_acc did not improve from 0.87983
# Epoch 15/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3676 - acc: 0.9320 - val_loss: 0.9743 - val_acc: 0.7739
#
# Epoch 00015: val_acc did not improve from 0.87983
# Epoch 16/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.4548 - acc: 0.9039 - val_loss: 0.5212 - val_acc: 0.8798
#
# Epoch 00016: val_acc did not improve from 0.87983
# Epoch 17/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3905 - acc: 0.9242 - val_loss: 0.6724 - val_acc: 0.8408
#
# Epoch 00017: val_acc did not improve from 0.87983
# Epoch 18/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3738 - acc: 0.9281 - val_loss: 0.4710 - val_acc: 0.8963
#
# Epoch 00018: val_acc improved from 0.87983 to 0.89625, saving model to /content/saved_models/XDB100_ResNet20v1_model.018.h5
# Epoch 19/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3232 - acc: 0.9460 - val_loss: 0.3899 - val_acc: 0.9195
#
# Epoch 00019: val_acc improved from 0.89625 to 0.91949, saving model to /content/saved_models/XDB100_ResNet20v1_model.019.h5
# Epoch 20/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2641 - acc: 0.9640 - val_loss: 0.4871 - val_acc: 0.8900
#
# Epoch 00020: val_acc did not improve from 0.91949
# Epoch 21/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3083 - acc: 0.9472 - val_loss: 0.5070 - val_acc: 0.8820
#
# Epoch 00021: val_acc did not improve from 0.91949
# Epoch 22/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3387 - acc: 0.9384 - val_loss: 0.4344 - val_acc: 0.9087
#
# Epoch 00022: val_acc did not improve from 0.91949
# Epoch 23/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3000 - acc: 0.9517 - val_loss: 0.4566 - val_acc: 0.9001
#
# Epoch 00023: val_acc did not improve from 0.91949
# Epoch 24/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2850 - acc: 0.9536 - val_loss: 0.4834 - val_acc: 0.8973
#
# Epoch 00024: val_acc did not improve from 0.91949
# Epoch 25/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3159 - acc: 0.9465 - val_loss: 0.4737 - val_acc: 0.8945
#
# Epoch 00025: val_acc did not improve from 0.91949
# Epoch 26/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3449 - acc: 0.9375 - val_loss: 0.5760 - val_acc: 0.8810
#
# Epoch 00026: val_acc did not improve from 0.91949
# Epoch 27/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2860 - acc: 0.9569 - val_loss: 0.4445 - val_acc: 0.9051
#
# Epoch 00027: val_acc did not improve from 0.91949
# Epoch 28/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3331 - acc: 0.9397 - val_loss: 0.4746 - val_acc: 0.8995
#
# Epoch 00028: val_acc did not improve from 0.91949
# Epoch 29/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2963 - acc: 0.9538 - val_loss: 0.4016 - val_acc: 0.9181
#
# Epoch 00029: val_acc did not improve from 0.91949
# Epoch 30/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2339 - acc: 0.9729 - val_loss: 0.4447 - val_acc: 0.9093
#
# Epoch 00030: val_acc did not improve from 0.91949
# Epoch 31/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3115 - acc: 0.9476 - val_loss: 0.6128 - val_acc: 0.8698
#
# Epoch 00031: val_acc did not improve from 0.91949
# Epoch 32/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.3304 - acc: 0.9397 - val_loss: 0.4410 - val_acc: 0.9117
#
# Epoch 00032: val_acc did not improve from 0.91949
# Epoch 33/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2234 - acc: 0.9761 - val_loss: 0.5000 - val_acc: 0.8957
#
# Epoch 00033: val_acc did not improve from 0.91949
# Epoch 34/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2647 - acc: 0.9621 - val_loss: 0.4363 - val_acc: 0.9143
#
# Epoch 00034: val_acc did not improve from 0.91949
# Epoch 35/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2871 - acc: 0.9565 - val_loss: 0.5895 - val_acc: 0.8786
#
# Epoch 00035: val_acc did not improve from 0.91949
# Epoch 36/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2597 - acc: 0.9633 - val_loss: 0.4354 - val_acc: 0.9101
#
# Epoch 00036: val_acc did not improve from 0.91949
# Epoch 37/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2685 - acc: 0.9617 - val_loss: 0.3936 - val_acc: 0.9253
#
# Epoch 00037: val_acc improved from 0.91949 to 0.92530, saving model to /content/saved_models/XDB100_ResNet20v1_model.037.h5
# Epoch 38/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2462 - acc: 0.9675 - val_loss: 0.4120 - val_acc: 0.9203
#
# Epoch 00038: val_acc did not improve from 0.92530
# Epoch 39/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2078 - acc: 0.9818 - val_loss: 0.3403 - val_acc: 0.9401
#
# Epoch 00039: val_acc improved from 0.92530 to 0.94012, saving model to /content/saved_models/XDB100_ResNet20v1_model.039.h5
# Epoch 40/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2184 - acc: 0.9765 - val_loss: 0.4002 - val_acc: 0.9223
#
# Epoch 00040: val_acc did not improve from 0.94012
# Epoch 41/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2840 - acc: 0.9564 - val_loss: 0.3234 - val_acc: 0.9427
#
# Epoch 00041: val_acc improved from 0.94012 to 0.94272, saving model to /content/saved_models/XDB100_ResNet20v1_model.041.h5
# Epoch 42/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2675 - acc: 0.9601 - val_loss: 0.3563 - val_acc: 0.9363
#
# Epoch 00042: val_acc did not improve from 0.94272
# Epoch 43/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2816 - acc: 0.9576 - val_loss: 0.4556 - val_acc: 0.9113
#
# Epoch 00043: val_acc did not improve from 0.94272
# Epoch 44/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2850 - acc: 0.9556 - val_loss: 0.3975 - val_acc: 0.9229
#
# Epoch 00044: val_acc did not improve from 0.94272
# Epoch 45/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 33s 3ms/step - loss: 0.2319 - acc: 0.9713 - val_loss: 0.5140 - val_acc: 0.8955
#
# Epoch 00045: val_acc did not improve from 0.94272
# Epoch 46/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 33s 3ms/step - loss: 0.3651 - acc: 0.9360 - val_loss: 0.4824 - val_acc: 0.9011
#
# Epoch 00046: val_acc did not improve from 0.94272
# Epoch 47/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 33s 3ms/step - loss: 0.3101 - acc: 0.9506 - val_loss: 0.4487 - val_acc: 0.9157
#
# Epoch 00047: val_acc did not improve from 0.94272
# Epoch 48/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 34s 3ms/step - loss: 0.2346 - acc: 0.9735 - val_loss: 0.3742 - val_acc: 0.9321
#
# Epoch 00048: val_acc did not improve from 0.94272
# Epoch 49/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 33s 3ms/step - loss: 0.2462 - acc: 0.9694 - val_loss: 0.3714 - val_acc: 0.9327
#
# Epoch 00049: val_acc did not improve from 0.94272
# Epoch 50/50
# Learning rate:  0.001
# 11649/11649 [==============================] - 33s 3ms/step - loss: 0.2548 - acc: 0.9668 - val_loss: 0.4275 - val_acc: 0.9207
#
# Epoch 00050: val_acc did not improve from 0.94272
# 4993/4993 [==============================] - 4s 882us/step
# Test loss: 0.4274751603507862
# Test accuracy: 0.9206889645503705
